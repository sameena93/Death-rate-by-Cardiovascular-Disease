# %%
# ! pip install jupyter_datatables
# ! pip install qgrid

# Import the necessary module or library where 'register' is defined
from some_module import register

# Call the 'register' function with the 'widget' argument
widget_instance = Widget()  # Replace 'Widget()' with your actual widget instance
register(widget_instance)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 5
#       1 # ! pip install jupyter_datatables
#       2 # ! pip install qgrid
#       3
#       4 # Import the necessary module or library where 'register' is defined
# ----> 5 from some_module import register
#       7 # Call the 'register' function with the 'widget' argument
#       8 widget_instance = Widget()  # Replace 'Widget()' with your actual widget instance
#
# ModuleNotFoundError: No module named 'some_module'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from jupyter_datatables import init_datatables_mode
import qgrid
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       3 import matplotlib.pyplot as plt
#       4 from jupyter_datatables import init_datatables_mode
# ----> 5 import qgrid
#
# File ~\anaconda3\Lib\site-packages\qgrid\__init__.py:3
#       1 from ._version import version_info, __version__  # noqa F401
# ----> 3 from .grid import (
#       4     enable,
#       5     disable,
#       6     set_defaults,
#       7     on,
#       8     off,
#       9     set_grid_option,
#      10     show_grid,
#      11     QgridWidget,
#      12     QGridWidget,
#      13 )
#      16 def _jupyter_nbextension_paths():
#      17     return [
#      18         {
#      19             "section": "notebook",
#    (...)
#      23         }
#      24     ]
#
# File ~\anaconda3\Lib\site-packages\qgrid\grid.py:524
#     520     else:
#     521         return str(x)
# ...

# %%
# init_datatables_mode()
# Out:
# ---------------------------------------------------------------------------
# CommError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 init_datatables_mode()
#
# File ~\anaconda3\Lib\site-packages\jupyter_datatables\__init__.py:96, in init_datatables_mode(options, classes)
#      93 # extensions to be loaded
#      94 extensions = config.defaults.extensions
# ---> 96 require("d3", "https://d3js.org/d3.v5.min")
#      97 require("d3-array", "https://d3js.org/d3-array.v2.min")
#      99 require.config(**{
#     100     "paths": {
#     101         "moment": "https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.8.0/moment",
#    (...)
#     109     },
#     110 })
#
# File ~\anaconda3\Lib\site-packages\jupyter_require\core.py:112, in RequireJS.__call__(self, library, path, *args, **kwargs)
#      98 def __call__(self, library: str, path: str, *args, **kwargs):
#      99     """Links JavaScript library to Jupyter Notebook.
#     100
# ...

# %%
df = pd.read_csv("../Final Project/Mujawar_Sameena_heart_failure_dataset.csv")

# %%
df
# Out:
#       age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0    75.0      No                       582       No                 20
# 1    55.0      No                      7861       No                 38
# 2    65.0      No                       146       No                 20
# 3    50.0     Yes                       111       No                 20
# 4    65.0     Yes                       160      Yes                 20
# ..    ...     ...                       ...      ...                ...
# 294  62.0      No                        61      Yes                 38
# 295  55.0      No                      1820       No                 38
# 296  45.0      No                      2060      Yes                 60
# 297  45.0      No                      2413       No                 38
# 298  50.0      No                       196       No                 45
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# ...

# %%
df.info()

# %%
df.describe()

# %%
df.shape

# %%
df.iloc[:5,:6]

# %%
df.iloc[:5,6:13]

# %%
df.nunique()

# %%
df.isna().sum()
